# %% [markdown]
# # Webscraping

# %%
from bs4 import BeautifulSoup

import requests as req

import os

import pandas as pd

from urllib.parse import urljoin

# %% [markdown]
# ### Simple request to retrieve webpage title

# %%
url = 'https://www.scwcsu.nhs.uk/about/our-values'

response = req.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')

    print('Webpage title:', soup.title.string)

else:
    print(f'Failed to fetch webpage: {response.status_code}')
# Out:
# Webpage title: Our values - NHS SCW Support and Transformation for Health and Care

# %% [markdown]
# ### Display the HTML for a page

# %%
print(soup.prettify()) # i.e. accessing the BeautifulSoup object created above
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-gb">
#  <head>
#   <!-- Google tag (gtag.js) -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-TGFSCM0BEC">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
# 		function gtag(){dataLayer.push(arguments);}
# 		gtag('js', new Date());
#
# 		gtag('config', 'G-TGFSCM0BEC');
#   </script>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <meta charset="utf-8"/>
#   <meta content="NHS SCW values" name="description"/>
#   <meta content="HELIX_ULTIMATE_GENERATOR_TEXT" name="generator"/>
#   <title>
#    Our values - NHS SCW Support and Transformation for Health and Care
#   </title>
#   <link href="/images/scwfavicon.ico" rel="icon" type="image/vnd.microsoft.icon"/>
#   <link href="https://www.scwcsu.nhs.uk/scw-search?format=opensearch" rel="search" title="OpenSearch NHS SCW Support and Transformation for Health and Care" type="application/opensearchdescription+xml"/>
#   <link href="/media/vendor/joomla-custom-elements/css/joomla-alert.min.css?0.2.0" rel="stylesheet">
#    <link href="//fonts.googleapis.com/css?family=Open Sans:100,100i,200,200i,300,300i,400,400i,500,500i,600,600i,700,700i,800,800i,900,900i&amp;subset=cyrillic-ext&amp;display=swap" media="none" onload='media="all"' rel="stylesheet">
#     <link href="/templates/shaper_helixultimate/css/bootstrap.min.css" rel="stylesheet"/>
#     <link href="/plugins/system/helixultimate/assets/css/system-j4.min.css" rel="stylesheet"/>
#     <link href="/media/system/css/joomla-fontawesome.min.css?1fd6164d16248c155fedd45e8ba37473" rel="stylesheet"/>
#     <link href="/templates/shaper_helixultimate/css/template.css" rel="stylesheet"/>
#     <link href="/templates/shaper_helixultimate/css/presets/default.css" rel="stylesheet"/>
#     <link href="/templates/shaper_helixultimate/css/custom.css" rel="stylesheet"/>
#     <link href="/modules/mod_djmegamenu/themes/default/css/djmegamenu.css?4.3.6.free" rel="stylesheet"/>
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/animate.css/4.1.1/animate.compat.min.css" rel="stylesheet"/>
#     <link href="/modules/mod_djmegamenu/mobilethemes/light/djmobilemenu.css?4.3.6.free" rel="stylesheet"/>
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet"/>
#     <style>
#      #mod-search-searchword102 {
# padding: 1px;
#     line-height: 1.2;
#     padding-left: 5px;
# }
# #sp-top-bar {
# background:#1C355E;
# }
#
# li.dj-up.itemid939 {
# display:none!important;
# }
#     </style>
#     <style>
#      body{font-family: 'Arial', sans-serif;font-size: 16px;text-decoration: none;}
#     </style>
#     <style>
#      h1{font-family: 'Open Sans', sans-serif;text-decoration: none;}
#     </style>
#     <style>
#      .sp-megamenu-parent > li > a, .sp-megamenu-parent > li > span, .sp-megamenu-parent .sp-dropdown li.sp-menu-item > a{font-family: 'Open Sans', sans-serif;font-size: 16px;text-decoration: none;}
#     </style>
#     <style>
#      .logo-image {height:110px;}.logo-image-phone {height:110px;}
#     </style>
#     <style>
#      #sp-bottom{ background-color:#1b345c; }
#     </style>
#     <style>
#      #sp-footer{ background-color:#026eaf;color:#ffffff; }
#     </style>
#     <style>
#      .dj-hideitem { display: none !important; }
#     </style>
#     <style>
#      @media (min-width: 980px) { #dj-megamenu142mobile { display: none; } }
# 		@media (max-width: 979px) { #dj-megamenu142, #dj-megamenu142sticky, #dj-megamenu142placeholder { display: none !important; } }
#     </style>
#     <script src="/media/vendor/jquery/js/jquery.min.js?3.7.1">
#     </script>
#     <script src="/media/legacy/js/jquery-noconflict.min.js?647005fc12b79b3ca2bb30c059899d5994e3e34d">
#     </script>
#     <script class="joomla-script-options new" type="application/json">
#      {"data":{"breakpoints":{"tablet":991,"mobile":480},"header":{"stickyOffset":"100"}},"joomla.jtext":{"MOD_FINDER_SEARCH_VALUE":"Search &hellip;","ERROR":"Error","MESSAGE":"Message","NOTICE":"Notice","WARNING":"Warning","JCLOSE":"Close","JOK":"OK","JOPEN":"Open"},"system.paths":{"root":"","rootFull":"https:\/\/www.scwcsu.nhs.uk\/","base":"","baseFull":"https:\/\/www.scwcsu.nhs.uk\/"},"csrf.token":"d4360940d85fbb48c92fe8182eed6364"}
#     </script>
#     <script src="/media/system/js/core.min.js?37ffe4186289eba9c5df81bea44080aff77b9684">
#     </script>
#     <script defer="" nomodule="" src="/media/vendor/bootstrap/js/bootstrap-es5.min.js?5.3.2">
#     </script>
#     <script defer="" nomodule="" src="/media/system/js/showon-es5.min.js?0e293ba9dec283752e25f4e1d5eb0a6f8c07d3be">
#     </script>
#     <script defer="" nomodule="" src="/media/com_finder/js/finder-es5.min.js?e6d3d1f535e33b5641e406eb08d15093e7038cc2">
#     </script>
#     <script defer="" nomodule="" src="/media/system/js/messages-es5.min.js?c29829fd2432533d05b15b771f86c6637708bd9d">
#     </script>
#     <script src="/media/vendor/bootstrap/js/alert.min.js?5.3.2" type="module">
#     </script>
#     <script src="/media/vendor/bootstrap/js/button.min.js?5.3.2" type="module">
#     </script>
#     <script src="/media/vendor/bootstrap/js/carousel.min.js?5.3.2" type="module">
#     </script>
#     <script src="/media/vendor/bootstrap/js/collapse.min.js?5.3.2" type="module">
#     </script>
#     <script src="/media/vendor/bootstrap/js/dropdown.min.js?5.3.2" type="module">
#     </script>
#     <script src="/media/vendor/bootstrap/js/modal.min.js?5.3.2" type="module">
#     </script>
#     <script src="/media/vendor/bootstrap/js/offcanvas.min.js?5.3.2" type="module">
#     </script>
#     <script src="/media/vendor/bootstrap/js/popover.min.js?5.3.2" type="module">
#     </script>
#     <script src="/media/vendor/bootstrap/js/scrollspy.min.js?5.3.2" type="module">
#     </script>
#     <script src="/media/vendor/bootstrap/js/tab.min.js?5.3.2" type="module">
#     </script>
#     <script src="/media/vendor/bootstrap/js/toast.min.js?5.3.2" type="module">
#     </script>
#     <script src="/media/system/js/showon.min.js?f79c256660e2c0ca2179cf7f3168ea8143e1af82" type="module">
#     </script>
#     <script src="/media/com_finder/js/finder.min.js?a2c3894d062787a266d59d457ffba5481b639f64" type="module">
#     </script>
#     <script src="/media/system/js/messages.min.js?7f7aa28ac8e8d42145850e8b45b3bc82ff9a6411" type="module">
#     </script>
#     <script src="/templates/shaper_helixultimate/js/main.js">
#     </script>
#     <script defer="" src="/modules/mod_djmegamenu/assets/js/jquery.djmegamenu.min.js?4.3.6.free">
#     </script>
#     <script defer="" src="/modules/mod_djmegamenu/assets/js/jquery.djmobilemenu.min.js?4.3.6.free">
#     </script>
#     <script>
#      template="shaper_helixultimate";
#     </script>
#     <meta content="article" property="og:type">
#      <meta content="https://www.scwcsu.nhs.uk/about/our-values" property="og:url">
#       <meta content="Our values" property="og:title">
#        <meta content="We are proud to be part of the NHS and guided by its principles. We believe passionately in five core values that underpin everything we do.
# " property="og:description">
#         <meta content="https://www.scwcsu.nhs.uk/images/1_Approved_images/Large_1110x450/Marianne_and_Sukyna_1110x450.jpg" property="og:image"/>
#         <meta content="NHS SCW Support and Transformation for Health and Care" property="og:site_name"/>
#         <meta content="We are proud to be part of the NHS and guided by its principles. We believe passionately in five core values that underpin everything we do.
# " name="twitter:description"/>
#         <meta content="https://www.scwcsu.nhs.uk/images/1_Approved_images/Large_1110x450/Marianne_and_Sukyna_1110x450.jpg" name="twitter:image:src"/>
#         <meta content="summary_large_image" name="twitter:card"/>
#         <link as="style" href="https://cdnjs.cloudflare.com/ajax/libs/animate.css/4.1.1/animate.compat.min.css" rel="stylesheet preload"/>
#         <link as="style" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet preload"/>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </link>
#   </link>
#  </head>
#  <body class="site helix-ultimate hu com_content com-content view-article layout-default task-none itemid-903 en-gb ltr layout-fluid offcanvas-init offcanvs-position-right">
#   <div class="dj-offcanvas-wrapper">
#    <div class="dj-offcanvas-pusher">
#     <div class="dj-offcanvas-pusher-in">
#      <div class="body-wrapper">
#       <div class="body-innerwrapper">
#        <div id="sp-top-bar">
#         <div class="container">
#          <div class="container-inner">
#           <div class="row">
#            <div class="col-lg-6" id="sp-top1">
#             <div class="sp-column text-center text-lg-left">
#             </div>
#            </div>
#            <div class="col-lg-6" id="sp-top2">
#             <div class="sp-column text-center text-lg-right">
#              <div class="sp-module searchbox float-right mod-search-searchicon227">
#               <div class="sp-module-content">
#                <form action="/scw-search" class="mod-finder js-finder-searchform form-search" method="get" role="search">
#                 <label class="visually-hidden finder" for="mod-finder-searchword227">
#                  Search
#                 </label>
#                 <div class="mod-finder__search input-group">
#                  <input class="js-finder-search-query form-control" id="mod-finder-searchword227" name="q" placeholder="Search" type="text" value=""/>
#                  <button aria-label="submit search" class="btn btn-primary" id="scw-searchbutton" type="submit">
#                   <img aria-hidden="true" src="/templates/shaper_helixultimate/images/searchButton.gif" style="
#     height: 26px;
# "/>
#                  </button>
#                 </div>
#                </form>
#               </div>
#              </div>
#              <div class="sp-module access-toolbar">
#               <div class="sp-module-content">
#                <div class="mod-custom custom" id="mod-custom188">
#                 <div id="__ba_panel">
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <header id="sp-header">
#         <div class="container">
#          <div class="container-inner">
#           <div class="row">
#            <div class="col-8 col-lg-3" id="sp-logo">
#             <div class="sp-column">
#              <div class="logo">
#               <a href="/">
#                <img alt="NHS SCW Support and Transformation for Health and Care" class="logo-image d-none d-lg-inline-block" height="110px" src="https://www.scwcsu.nhs.uk/images/logo.svg" srcset="https://www.scwcsu.nhs.uk/images/logo.svg 1x">
#                 <img alt="NHS SCW Support and Transformation for Health and Care" class="logo-image-phone d-inline-block d-lg-none" src="https://www.scwcsu.nhs.uk/images/logo@2x.svg"/>
#                </img>
#               </a>
#              </div>
#             </div>
#            </div>
#            <div class="col-4 col-lg-9" id="sp-logo-right">
#             <div class="sp-column">
#              <div class="sp-module scw-logo">
#               <div class="sp-module-content">
#                <div class="mod-custom custom" id="mod-custom112">
#                 <p>
#                  <img alt="National Health Service" src="/images/nhsbluelogo.jpg" style="max-width: 60%; float: right;"/>
#                 </p>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="row">
#            <div class="col-12" id="sp-menu">
#             <div class="sp-column">
#              <div class="sp-module djmenuoveride">
#               <div class="sp-module-content">
#                <div class="dj-megamenu-wrapper" data-joomla4="" data-tmpl="shaper_helixultimate">
#                 <ul aria-label="DJ-MegaMenu" class="dj-megamenu dj-megamenu-default dj-megamenu-wcag horizontalMenu dj-fa-1" data-options='{"wrap":null,"animIn":"0","animOut":"zoomOut","animSpeed":"normal","openDelay":0,"closeDelay":"500","event":"click_all","eventClose":"mouseleave","parentOpen":"0","fixed":0,"offset":"0","theme":"default","direction":"ltr","wcag":"1","overlay":"0"}' data-trigger="979" id="dj-megamenu142" role="menubar">
#                  <li class="dj-up itemid937 first parent" role="none">
#                   <a aria-expanded="false" aria-haspopup="true" class="dj-up_a" role="menuitem" tabindex="0">
#                    <span class="dj-drop">
#                     <span class="title">
#                      <span class="name">
#                       About us
#                      </span>
#                     </span>
#                     <span aria-hidden="true" class="arrow">
#                     </span>
#                    </span>
#                   </a>
#                   <div class="dj-subwrap open-right single_column subcols1" style="">
#                    <div class="dj-subwrap-in" style="width:200px;">
#                     <div class="dj-subcol" style="width:200px">
#                      <ul aria-label="About us" class="dj-submenu" role="menu">
#                       <li class="itemid775 first" role="none">
#                        <a href="/about/about-us" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           About us
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid902" role="none">
#                        <a href="/about/executive-board" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Executive Board
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid903" role="none">
#                        <a href="/about/our-values" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Our values
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid904" role="none">
#                        <a href="/about/people-and-wellbeing" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           People and wellbeing
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid905" role="none">
#                        <a href="/about/sustainability" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Sustainability
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid906" role="none">
#                        <a href="/about/contact-us" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Contact us
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid1160" role="none">
#                        <a href="/about/accreditations" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Accreditations
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid907" role="none">
#                        <a href="/about/our-impact" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Our impact
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                      </ul>
#                     </div>
#                    </div>
#                   </div>
#                  </li>
#                  <li class="dj-up itemid849 parent" role="none">
#                   <a aria-expanded="false" aria-haspopup="true" class="dj-up_a" role="menuitem" tabindex="0">
#                    <span class="dj-drop">
#                     <span class="title">
#                      <span class="name">
#                       Areas of work
#                      </span>
#                     </span>
#                     <span aria-hidden="true" class="arrow">
#                     </span>
#                    </span>
#                   </a>
#                   <div class="dj-subwrap open-right single_column subcols1" style="">
#                    <div class="dj-subwrap-in" style="width:200px;">
#                     <div class="dj-subcol" style="width:200px">
#                      <ul aria-label="Areas of work" class="dj-submenu" role="menu">
#                       <li class="itemid1074 first" role="none">
#                        <a href="/areas/analytics-and-business-intelligence" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Analytics and business intelligence
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid1070" role="none">
#                        <a href="/areas/clinical-support-services" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Clinical support services
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid1073" role="none">
#                        <a href="/areas/corporate-services" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Corporate services
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid1077" role="none">
#                        <a href="/areas/digital-data-and-technology" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Digital, data and technology
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid957" role="none">
#                        <a href="/areas/people-solutions" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           People solutions
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid1072" role="none">
#                        <a href="/areas/procurement-contracts-and-finance" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Procurement, contracts and finance
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid1075" role="none">
#                        <a href="/areas/public-health-services" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Public health services
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid1071" role="none">
#                        <a href="/areas/transformation-consultancy" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Transformation consultancy
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid1078" role="none">
#                        <a href="https://scwcsu.nhs.uk/case-studies" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Case studies
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid1080" role="none">
#                        <a href="/areas/products-and-services-catalogue" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Products and services catalogue
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid1142" role="none">
#                        <a href="/areas/thank-you" role="menuitem">
#                        </a>
#                       </li>
#                      </ul>
#                     </div>
#                    </div>
#                   </div>
#                  </li>
#                  <li class="dj-up itemid875 parent" role="none">
#                   <a aria-expanded="false" aria-haspopup="true" class="dj-up_a" role="menuitem" tabindex="0">
#                    <span class="dj-drop">
#                     <span class="title">
#                      <span class="name">
#                       Priorities
#                      </span>
#                     </span>
#                     <span aria-hidden="true" class="arrow">
#                     </span>
#                    </span>
#                   </a>
#                   <div class="dj-subwrap open-right single_column subcols1" style="">
#                    <div class="dj-subwrap-in" style="width:200px;">
#                     <div class="dj-subcol" style="width:200px">
#                      <ul aria-label="Priorities" class="dj-submenu" role="menu">
#                       <li class="itemid877 first" role="none">
#                        <a href="/priorities/digital-health-and-care" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Digital transformation
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid1168" role="none">
#                        <a href="/priorities/evolving-provider-collaboratives" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Evolving provider collaboratives
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid1076" role="none">
#                        <a href="/priorities/operational-efficiencies" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Operational efficiencies
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid1161" role="none">
#                        <a href="/priorities/population-health" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Population health
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid1009" role="none">
#                        <a href="/priorities/health-inequalities" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Health improvement and inequalities
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid876" role="none">
#                        <a href="/priorities/protecting-the-population" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Protecting the population
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid850" role="none">
#                        <a href="/priorities/primary-care" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           The future of Primary Care
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid1039" role="none">
#                        <a href="/priorities/people" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Workforce
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                      </ul>
#                     </div>
#                    </div>
#                   </div>
#                  </li>
#                  <li class="dj-up itemid1085 parent" role="none">
#                   <a aria-expanded="false" aria-haspopup="true" class="dj-up_a" role="menuitem" tabindex="0">
#                    <span class="dj-drop">
#                     <span class="title">
#                      <span class="name">
#                       NHS showcase
#                      </span>
#                     </span>
#                     <span aria-hidden="true" class="arrow">
#                     </span>
#                    </span>
#                   </a>
#                   <div class="dj-subwrap open-right single_column subcols1" style="">
#                    <div class="dj-subwrap-in" style="width:200px;">
#                     <div class="dj-subcol" style="width:200px">
#                      <ul aria-label="NHS showcase" class="dj-submenu" role="menu">
#                       <li class="itemid1086 first" role="none">
#                        <a href="/nhs-showcase/reporting-on-health-inequalities-to-nhs-trust-boards" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Reporting on health inequalities to NHS Trust Boards
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid1159" role="none">
#                        <a href="/nhs-showcase/evaluation-of-hearing-health-pathway-pilot-in-south-west-london-icb" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Evaluation of Hearing Health Pathway Pilot in South West London ICB
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid1162" role="none">
#                        <a href="/nhs-showcase/south-east-region-learning-stories" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           South East region learning stories
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid1169" role="none">
#                        <a href="/nhs-showcase/report-how-are-ics-strategies-and-joint-forward-plans-addressing-health-inequalities" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Report: How are ICS strategies and Joint Forward Plans addressing health inequalities?
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid1170" role="none">
#                        <a href="/nhs-showcase/addressing-health-inequalities-through-making-every-contact-count-mecc" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Addressing health inequalities through Making Every Contact Count (MECC)
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                      </ul>
#                     </div>
#                    </div>
#                   </div>
#                  </li>
#                  <li class="dj-up itemid540" role="none">
#                   <a class="dj-up_a" href="/news-and-views" role="menuitem">
#                    <span>
#                     <span class="title">
#                      <span class="name">
#                       News and views
#                      </span>
#                     </span>
#                    </span>
#                   </a>
#                  </li>
#                  <li class="dj-up itemid886 parent" role="none">
#                   <a aria-expanded="false" aria-haspopup="true" class="dj-up_a" role="menuitem" tabindex="0">
#                    <span class="dj-drop">
#                     <span class="title">
#                      <span class="name">
#                       Work for us
#                      </span>
#                     </span>
#                     <span aria-hidden="true" class="arrow">
#                     </span>
#                    </span>
#                   </a>
#                   <div class="dj-subwrap open-right single_column subcols1" style="">
#                    <div class="dj-subwrap-in" style="width:200px;">
#                     <div class="dj-subcol" style="width:200px">
#                      <ul aria-label="Work for us " class="dj-submenu" role="menu">
#                       <li class="itemid884 first" role="none">
#                        <a href="/work-for-us/vacancies?view=nhsjobs" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Vacancies
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid909" role="none">
#                        <a href="/work-for-us/application-process" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Application Process
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid914" role="none">
#                        <a href="/work-for-us/graduate-scheme" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Graduate scheme
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid910" role="none">
#                        <a href="/work-for-us/early-careers" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Early careers
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid912" role="none">
#                        <a href="/work-for-us/armed-forces" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Armed Forces
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid913" role="none">
#                        <a href="/work-for-us/life-at-scw" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Life at SCW
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="itemid1081" role="none">
#                        <a href="/work-for-us/careers-and-recruitment-events" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Careers and recruitment events
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                      </ul>
#                     </div>
#                    </div>
#                   </div>
#                  </li>
#                 </ul>
#                 <div class="dj-megamenu-accordion dj-megamenu-accordion-light dj-pos-absolute dj-align-right dj-fa-1 djmenuoveride" id="dj-megamenu142mobile">
#                  <button aria-label="Open mobile menu" class="dj-mobile-open-btn dj-fa-1">
#                   <span aria-hidden="true" class="dj-mobile-open-icon">
#                   </span>
#                  </button>
#                  <div class="dj-accordion dj-accordion-light djmenuoveride">
#                   <div class="dj-accordion-in">
#                    <ul class="dj-mobile-nav dj-mobile-light djmenuoveride" role="menubar">
#                     <li class="dj-mobileitem itemid-937 deeper parent" role="none">
#                      <a aria-expanded="false" aria-haspopup="true" role="menuitem" tabindex="0">
#                       <span class="title">
#                        <span class="name">
#                         About us
#                        </span>
#                       </span>
#                      </a>
#                      <ul class="dj-mobile-nav-child">
#                       <li class="dj-mobileitem itemid-775" role="none">
#                        <a href="/about/about-us" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           About us
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="dj-mobileitem itemid-902" role="none">
#                        <a href="/about/executive-board" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Executive Board
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="dj-mobileitem itemid-903" role="none">
#                        <a href="/about/our-values" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Our values
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="dj-mobileitem itemid-904" role="none">
#                        <a href="/about/people-and-wellbeing" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           People and wellbeing
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="dj-mobileitem itemid-905" role="none">
#                        <a href="/about/sustainability" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Sustainability
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="dj-mobileitem itemid-906" role="none">
#                        <a href="/about/contact-us" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Contact us
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="dj-mobileitem itemid-1160" role="none">
#                        <a href="/about/accreditations" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Accreditations
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="dj-mobileitem itemid-907" role="none">
#                        <a href="/about/our-impact" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Our impact
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                      </ul>
#                     </li>
#                     <li class="dj-mobileitem itemid-849 deeper parent" role="none">
#                      <a aria-expanded="false" aria-haspopup="true" role="menuitem" tabindex="0">
#                       <span class="title">
#                        <span class="name">
#                         Areas of work
#                        </span>
#                       </span>
#                      </a>
#                      <ul class="dj-mobile-nav-child">
#                       <li class="dj-mobileitem itemid-1074" role="none">
#                        <a href="/areas/analytics-and-business-intelligence" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Analytics and business intelligence
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="dj-mobileitem itemid-1070" role="none">
#                        <a href="/areas/clinical-support-services" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Clinical support services
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="dj-mobileitem itemid-1073" role="none">
#                        <a href="/areas/corporate-services" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Corporate services
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="dj-mobileitem itemid-1077" role="none">
#                        <a href="/areas/digital-data-and-technology" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Digital, data and technology
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="dj-mobileitem itemid-957" role="none">
#                        <a href="/areas/people-solutions" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           People solutions
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="dj-mobileitem itemid-1072" role="none">
#                        <a href="/areas/procurement-contracts-and-finance" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Procurement, contracts and finance
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="dj-mobileitem itemid-1075" role="none">
#                        <a href="/areas/public-health-services" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Public health services
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="dj-mobileitem itemid-1071" role="none">
#                        <a href="/areas/transformation-consultancy" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Transformation consultancy
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="dj-mobileitem itemid-1078" role="none">
#                        <a href="https://scwcsu.nhs.uk/case-studies" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Case studies
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="dj-mobileitem itemid-1080" role="none">
#                        <a href="/areas/products-and-services-catalogue" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Products and services catalogue
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="dj-mobileitem itemid-1142" role="none">
#                        <a href="/areas/thank-you" role="menuitem">
#                        </a>
#                       </li>
#                      </ul>
#                     </li>
#                     <li class="dj-mobileitem itemid-875 deeper parent" role="none">
#                      <a aria-expanded="false" aria-haspopup="true" role="menuitem" tabindex="0">
#                       <span class="title">
#                        <span class="name">
#                         Priorities
#                        </span>
#                       </span>
#                      </a>
#                      <ul class="dj-mobile-nav-child">
#                       <li class="dj-mobileitem itemid-877" role="none">
#                        <a href="/priorities/digital-health-and-care" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Digital transformation
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="dj-mobileitem itemid-1168" role="none">
#                        <a href="/priorities/evolving-provider-collaboratives" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Evolving provider collaboratives
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="dj-mobileitem itemid-1076" role="none">
#                        <a href="/priorities/operational-efficiencies" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Operational efficiencies
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="dj-mobileitem itemid-1161" role="none">
#                        <a href="/priorities/population-health" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Population health
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="dj-mobileitem itemid-1009" role="none">
#                        <a href="/priorities/health-inequalities" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Health improvement and inequalities
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="dj-mobileitem itemid-876" role="none">
#                        <a href="/priorities/protecting-the-population" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Protecting the population
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="dj-mobileitem itemid-850" role="none">
#                        <a href="/priorities/primary-care" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           The future of Primary Care
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="dj-mobileitem itemid-1039" role="none">
#                        <a href="/priorities/people" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Workforce
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                      </ul>
#                     </li>
#                     <li class="dj-mobileitem itemid-1085 deeper parent" role="none">
#                      <a aria-expanded="false" aria-haspopup="true" role="menuitem" tabindex="0">
#                       <span class="title">
#                        <span class="name">
#                         NHS showcase
#                        </span>
#                       </span>
#                      </a>
#                      <ul class="dj-mobile-nav-child">
#                       <li class="dj-mobileitem itemid-1086" role="none">
#                        <a href="/nhs-showcase/reporting-on-health-inequalities-to-nhs-trust-boards" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Reporting on health inequalities to NHS Trust Boards
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="dj-mobileitem itemid-1159" role="none">
#                        <a href="/nhs-showcase/evaluation-of-hearing-health-pathway-pilot-in-south-west-london-icb" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           Evaluation of Hearing Health Pathway Pilot in South West London ICB
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="dj-mobileitem itemid-1162" role="none">
#                        <a href="/nhs-showcase/south-east-region-learning-stories" role="menuitem">
#                         <span class="title">
#                          <span class="name">
#                           South East region learning stories
#                          </span>
#                         </span>
#                        </a>
#                       </li>
#                       <li class="dj-mobileitem itemid-1169" role="none">
# ...
#                 <div class="article-social-share">
#                  <div class="social-share-icon">
#                   <ul>
#                    <li>
#                     <a class="facebook" href="https://www.facebook.com/sharer.php?u=https://www.scwcsu.nhs.uk/about/our-values" onclick="window.open('https://www.facebook.com/sharer.php?u=https://www.scwcsu.nhs.uk/about/our-values','Facebook','width=600,height=300,left='+(screen.availWidth/2-300)+',top='+(screen.availHeight/2-150)+''); return false;" title="HELIX_ULTIMATE_SHARE_FACEBOOK">
#                      <span aria-hidden="true" class="fab fa-facebook">
#                      </span>
#                     </a>
#                    </li>
#                    <li>
#                     <a class="twitter" href="https://twitter.com/share?url=https://www.scwcsu.nhs.uk/about/our-values&amp;text=Our%20values" onclick="window.open('https://twitter.com/share?url=https://www.scwcsu.nhs.uk/about/our-values&amp;text=Our%20values','Twitter share','width=600,height=300,left='+(screen.availWidth/2-300)+',top='+(screen.availHeight/2-150)+''); return false;" title="HELIX_ULTIMATE_SHARE_TWITTER">
#                      <span aria-hidden="true" class="fab fa-twitter">
#                      </span>
#                     </a>
#                    </li>
#                    <li>
#                     <a class="linkedin" href="https://www.linkedin.com/shareArticle?mini=true&amp;url=https://www.scwcsu.nhs.uk/about/our-values" onclick="window.open('https://www.linkedin.com/shareArticle?mini=true&amp;url=https://www.scwcsu.nhs.uk/about/our-values','Linkedin','width=585,height=666,left='+(screen.availWidth/2-292)+',top='+(screen.availHeight/2-333)+''); return false;" title="HELIX_ULTIMATE_SHARE_LINKEDIN">
#                      <span aria-hidden="true" class="fab fa-linkedin">
#                      </span>
#                     </a>
#                    </li>
#                   </ul>
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <div class="row">
#                <div class="col-8" itemprop="articleBody">
#                 <p>
#                  We are proud to be part of the NHS and guided by its principles. We believe passionately in five core values that underpin everything we do.
#                 </p>
#                 <p>
#                  The SCW values inspire and guide us in how we work and the decisions we make.
#                 </p>
#                 <p>
#                  <img alt="Icon of a heart implying 'Patients first'" height="85" src="/images/2_Graphics/value_patients_first_small.jpg" title="Patients first" width="170"/>
#                 </p>
#                 <p>
#                  <strong>
#                   Patients First
#                  </strong>
#                  (Making a difference to people's lives through our partnerships)
#                 </p>
#                 <p>
#                  Our key inspiration is to make a difference to the lives of people, patients, communities and populations by providing effective services, solutions and support to our partners.
#                 </p>
#                 <p>
#                  <img alt="Icon of a rocket to impy Aspirational" height="85" src="/images/2_Graphics/value_aspirational_small.jpg" title="Aspirational" width="170"/>
#                 </p>
#                 <p>
#                  <strong>
#                   Aspirational
#                  </strong>
#                  (Delivering high quality)
#                 </p>
#                 <p>
#                  We are ambitious in the pursuit of excellence. We are focused on quality, always learning, and drive innovation finding new ways of working.
#                 </p>
#                 <p>
#                  <img alt="Icon of some people to imply Collaboration" height="85" src="/images/2_Graphics/value_collaborative_small.jpg" title="Collaboration" width="170"/>
#                 </p>
#                 <p>
#                  <strong>
#                   Collaborative
#                  </strong>
#                  (Working together effectively)
#                 </p>
#                 <p>
#                  We prioritise building and maintaining close partnerships with our colleagues and partners, working together as the 'SCW team' encouraging and appreciating contributions to achieve shared goals.
#                 </p>
#                 <p>
#                  <img alt="Icon of a lightbulb implying Insightful" height="85" src="/images/2_Graphics/value_insightful_small.jpg" title="Insightful" width="170"/>
#                 </p>
#                 <p>
#                  <strong>
#                   Insightful
#                  </strong>
#                  (Exploring new possibilities)
#                 </p>
#                 <p>
#                  Our skilled colleagues strive to understand different perspectives, opportunities, and challenges and explore new possibilities so that we can provide helpful solutions.
#                 </p>
#                 <p>
#                  <img alt="Icon of a handshake implying Respectful" height="85" src="/images/2_Graphics/value_respect_small.jpg" title="Respectful" width="170"/>
#                 </p>
#                 <p>
#                  <strong>
#                   Respectful
#                  </strong>
#                  (Respecting each other)
#                 </p>
#                 <p>
#                  We treat everyone fairly, with kindness and respect, valuing different perspectives, experiences, knowledge and skills - involving our people and partners in decisions.
#                 </p>
#                 <hr/>
#                 <h2>
#                 </h2>
#                 <p>
#                  <strong>
#                   Find out more about joining and working for us:
#                   <a href="/work-for-us/life-at-scw">
#                    SCW life
#                   </a>
#                  </strong>
#                 </p>
#                </div>
#                <div class="col-4">
#                 <div class="moduletable">
#                  <h3>
#                   Related articles
#                  </h3>
#                  <div class="sidebar-articles custom">
#                   <div class="row">
#                    <div class="col">
#                     <div class="sppb-addon-article">
#                      <a class="sppb-article-img-wrap" href="/about/our-impact" itemprop="url">
#                       <img alt="Woman wearing a face mask" class="sppb-img-responsive" itemprop="thumbnailUrl" loading="lazy" src="/images/1_Approved_images/Small_320x160/scw_small_0029_Layer_107.jpg"/>
#                      </a>
#                      <div class="sppb-article-info-wrap">
#                       <h3>
#                        <a href="/about/our-impact" itemprop="url">
#                         Our impact
#                        </a>
#                       </h3>
#                       <div class="sppb-article-introtext">
#                        <p>
#                         Through partnerships with NHS and non-NHS organisations, we continue to deliver against our stated purpose - supporting our customers to achieve the best possible outcomes for people, communities and populations.
#                        </p>
#                       </div>
#                      </div>
#                     </div>
#                    </div>
#                   </div>
#                   <div class="row">
#                    <div class="col">
#                     <div class="sppb-addon-article">
#                      <a class="sppb-article-img-wrap" href="/about/people-and-wellbeing" itemprop="url">
#                       <img alt="Female worker at desk in wheelchair wearing headphones" class="sppb-img-responsive" itemprop="thumbnailUrl" loading="lazy" src="/images/1_Approved_images/Small_320x160/Female_worker_wheelchair_headphones_small_131.jpg"/>
#                      </a>
#                      <div class="sppb-article-info-wrap">
#                       <h3>
#                        <a href="/about/people-and-wellbeing" itemprop="url">
#                         People and wellbeing
#                        </a>
#                       </h3>
#                       <div class="sppb-article-introtext">
#                        <p>
#                         At SCW we truly value equality, diversity and inclusion. We want to ensure that this is an equitable workplace where wellbeing is at the heart of everything we do and employees are encouraged to be their extraordinary selves and thrive.
#                        </p>
#                       </div>
#                      </div>
#                     </div>
#                    </div>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </main>
#           </div>
#          </div>
#         </div>
#        </section>
#        <section id="sp-bottom">
#         <div class="container">
#          <div class="container-inner">
#           <div class="row">
#            <div class="col-sm-col-sm-6 col-lg-4" id="sp-bottom1">
#             <div class="sp-column">
#              <div class="sp-module">
#               <h3 class="sp-module-title">
#                Quick Links
#               </h3>
#               <div class="sp-module-content">
#                <ul class="menu">
#                 <li class="item-966">
#                  <a href="/services">
#                   Services
#                  </a>
#                 </li>
#                 <li class="item-967">
#                  <a href="/case-studies">
#                   Case studies
#                  </a>
#                 </li>
#                 <li class="item-484">
#                  <a href="/about/contact-us">
#                   Contact us
#                  </a>
#                 </li>
#                 <li class="item-969">
#                  <a href="/events">
#                   Events
#                  </a>
#                 </li>
#                 <li class="item-970">
#                  <a href="/media-link">
#                   Media
#                  </a>
#                 </li>
#                 <li class="item-971">
#                  <a href="/newsletter-signup">
#                   Newsletter sign-up
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="col-sm-col-sm-6 col-lg-4" id="sp-bottom2">
#             <div class="sp-column">
#              <div class="sp-module">
#               <h3 class="sp-module-title">
#                Connect
#               </h3>
#               <div class="sp-module-content">
#                <div class="mod-custom custom" id="mod-custom94">
#                 <div class="pull-left">
#                  <ul>
#                   <li class="global-footer__social__item">
#                    <a class="global-footer__social__anchor" href="https://www.youtube.com/channel/UCdbBibmeyZrWlWdIZD4T82g" title="YouTube">
#                     <span class="fa fa-youtube">
#                     </span>
#                     YouTube
#                    </a>
#                    <!-- .global-footer__social__anchor -->
#                   </li>
#                  </ul>
#                  <!-- .global-footer__social__item -->
#                  <ul>
#                   <li class="global-footer__social__item">
#                    <a class="global-footer__social__anchor" href="https://twitter.com/NHSscw/" title="X">
#                     <span class="fa-brands fa-x-twitter">
#                     </span>
#                     X Twitter
#                    </a>
#                    <!-- .global-footer__social__anchor -->
#                   </li>
#                  </ul>
#                  <!-- .global-footer__social__item -->
#                  <ul>
#                   <li class="global-footer__social__item">
#                    <a class="global-footer__social__anchor" href="https://www.linkedin.com/company/south-central-and-west-csu/" title="LinkedIn">
#                     <span class="fa fa-linkedin-square">
#                     </span>
#                     LinkedIn
#                    </a>
#                    <!-- .global-footer__social__anchor -->
#                   </li>
#                  </ul>
#                  <!-- .global-footer__social__item -->
#                  <ul>
#                   <li class="global-footer__social__item">
#                    <a class="global-footer__social__anchor" href="https://www.instagram.com/nhsscw/" title="Instagram">
#                     <span class="fa fa-instagram">
#                     </span>
#                     Instagram
#                    </a>
#                    <!-- .global-footer__social__anchor -->
#                   </li>
#                  </ul>
#                  <!-- .global-footer__social__item -->
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="col-lg-4" id="sp-bottom3">
#             <div class="sp-column">
#              <div class="sp-module">
#               <h3 class="sp-module-title">
#                Latest Tweets
#               </h3>
#               <div class="sp-module-content">
#                <div class="mod-custom custom" id="mod-custom139">
#                 <a class="twitter-timeline" data-height="300" data-width="100%" href="https://twitter.com/nhsscw">
#                  Tweets by @NHSscw
#                 </a>
#                 <script async="" charset="utf-8" src="https://platform.twitter.com/widgets.js">
#                 </script>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </section>
#        <footer id="sp-footer">
#         <div class="container">
#          <div class="container-inner">
#           <div class="row">
#            <div class="col-lg-3" id="sp-footer2">
#             <div class="sp-column">
#              <span class="sp-copyright">
#               ©2024 Copyright SCW
#              </span>
#             </div>
#            </div>
#            <div class="col-lg-9" id="sp-footer1">
#             <div class="sp-column">
#              <div class="sp-module">
#               <div class="sp-module-content">
#                <ul class="menu">
#                 <li class="item-941">
#                  <a href="/privacy-and-cookies">
#                   Privacy and Cookies
#                  </a>
#                 </li>
#                 <li class="item-943">
#                  <a href="/accessibility">
#                   Accessibility
#                  </a>
#                 </li>
#                 <li class="item-946">
#                  <a href="/fair-processing">
#                   Fair Processing
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#              <div class="sp-module">
#               <div class="sp-module-content">
#                <div class="mod-custom custom" id="mod-custom189">
#                 <script crossorigin="anonymous" integrity="sha256-VCrJcQdV3IbbIVjmUyF7DnCqBbWD1BcZ/1sda2KWeFc= sha384-k2OQFn+wNFrKjU9HiaHAcHlEvLbfsVfvOnpmKBGWVBrpmGaIleDNHnnCJO4z2Y2H sha512-gxDfysgvGhVPSHDTieJ/8AlcIEjFbF3MdUgZZL2M5GXXDdIXCcX0CpH7Dh6jsHLOLOjRzTFdXASWZtxO+eMgyQ==" src="https://www.browsealoud.com/plus/scripts/3.1.0/ba.js" type="text/javascript">
#                 </script>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </footer>
#       </div>
#      </div>
#      <!-- Off Canvas Menu -->
#      <div class="offcanvas-overlay">
#      </div>
#      <!-- Rendering the offcanvas style -->
#      <!-- If canvas style selected then render the style -->
#      <!-- otherwise (for old templates) attach the offcanvas module position -->
#      <!-- Go to top -->
#      <a aria-label="HELIX_ULTIMATE_SCROLL_UP_ARIA_LABEL" class="sp-scroll-up" href="#">
#       <span aria-hidden="true" class="fas fa-angle-up">
#       </span>
#      </a>
#     </div>
#    </div>
#   </div>
#   <script async="" src="/_Incapsula_Resource?SWJIYLWA=719d34d31c8e3a6e6fffd425f7e032f3&amp;ns=1&amp;cb=833412508" type="text/javascript">
#   </script>
#  </body>
# </html>

# %% [markdown]
# ### Locate a .csv file on a webpage

# %%
url2 = ('https://digital.nhs.uk/data-and-information/publications/statistical/out-of-area-placements-in-mental-health-services/march-2024') 

response2 = req.get(url2)

if response2.status_code == 200:
    soup2 = BeautifulSoup(response2.content, 'html.parser')
    csv_link = soup2.find("a", href=lambda href: href and href.endswith('csv'))
    file_url = csv_link["href"]
    print("Found .csv file:", file_url)

else:
    print(f'Failed to fetch webpage: {response2.status_code}')
# Out:
# Found .csv file: https://files.digital.nhs.uk/32/0B358C/oaps-open-data-mar-2024.csv

# %% [markdown]
# ### Check the response and download the file to the current directory

# %%
file_name = file_url.split("/")[-1]  # Extract the file name from the URL i.e. the bit after the last "/"
file_response = req.get(file_url)

if file_response.status_code == 200:
    # Save the file to the current directory
    with open(f'{file_name}', "wb") as file:
        file.write(file_response.content)
    print(f"Downloaded: {file_name}")
else:
    print(f"Failed to download: {file_url}")
# Out:
# Downloaded: oaps-open-data-mar-2024.csv

# %% [markdown]
# ### Read the .csv directly into a Pandas dataframe

# %%
from io import StringIO                     # io is native to Python

csv_content = StringIO(file_response.text)  # convert the context to a file-like object

df = pd.read_csv(csv_content)

df.head()
# Out:
# C:\Users\edward.chick\AppData\Local\Temp\ipykernel_1752\2620690345.py:5: DtypeWarning: Columns (7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_content)
#   Grouping      PublicationPeriod PublicationDate  \
# 0    Month  01/03/2024-31/03/2024         2024/06
# 1    Month  01/03/2024-31/03/2024         2024/06
# 2    Month  01/03/2024-31/03/2024         2024/06
# 3    Month  01/03/2024-31/03/2024         2024/06
# 4    Month  01/03/2024-31/03/2024         2024/06
#
#                                             Question Breakdown1  \
# 0        Average recorded daily cost over the period    BedType
# 1          Lower quartile daily cost over the period    BedType
# 2  Number of OAPs active during the period with a...    BedType
# 3  Number of OAPs active during the period with a...    BedType
# 4  Number of OAPs active during the period with a...    BedType
#
#   Breakdown1Code           Breakdown1Description Breakdown2 Breakdown2Code  \
# 0             10  Acute adult mental health care        NaN            NaN
# 1             10  Acute adult mental health care        NaN            NaN
# 2             10  Acute adult mental health care        NaN            NaN
# 3             10  Acute adult mental health care        NaN            NaN
# 4             10  Acute adult mental health care        NaN            NaN
#
#   Breakdown2Description Value
# 0                   NaN   695
# 1                   NaN   576
# 2                   NaN   280
# 3                   NaN   195
# 4                   NaN    50

# %% [markdown]
# ### Download multiple files of a particular type from a webpage

# %%
url3 = ('https://www.england.nhs.uk/statistics/statistical-work-areas/serious-mental-illness-smi/')

response3 = req.get(url3)

if response3.status_code == 200:
    soup3 = BeautifulSoup(response3.content, "html.parser")
    
  
    for link in soup3.find_all("a", href=True):
        file_url = link["href"]
        if file_url.endswith(('.xlsx')):  # Check for .xlsx file extensions
            print("Found .xlsx file:", file_url)
            
            # Step 4: Download the file
            file_name = file_url.split("/")[-1]  # Extract the file name from the URL i.e. everything after the last /
            file_response = req.get(file_url)
            
            if file_response.status_code == 200:
                # Save the file to the current directory
                with open(file_name, "wb") as file:
                    file.write(file_response.content)
                print(f"Downloaded: {file_name}")
            else:
                print(f"Failed to download: {file_url}")
    
else:
    print(f"Failed to fetch webpage: {response.status_code}")
# Out:
# Found .xlsx file: https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2024/05/PH-SMI-Q4-2023-24.xlsx
# Downloaded: PH-SMI-Q4-2023-24.xlsx
# Found .xlsx file: https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2024/02/Physical-Health-Checks-SMI-Q3-2023-24.xlsx
# Downloaded: Physical-Health-Checks-SMI-Q3-2023-24.xlsx
# Found .xlsx file: https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2023/11/Physical-Health-Checks-SMI-Q2-2023-24.xlsx
# Downloaded: Physical-Health-Checks-SMI-Q2-2023-24.xlsx
# Found .xlsx file: https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2023/11/Physical-Health-Checks-SMI-Q1-2023-24-Revised-v2.xlsx
# Downloaded: Physical-Health-Checks-SMI-Q1-2023-24-Revised-v2.xlsx
# Found .xlsx file: https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2023/05/Physical-Health-Checks-SMI-Q4-2022-23-1.xlsx
# Downloaded: Physical-Health-Checks-SMI-Q4-2022-23-1.xlsx
# Found .xlsx file: https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2023/02/Physical-Health-Checks-SMI-Q3-2022-23.xlsx
# Downloaded: Physical-Health-Checks-SMI-Q3-2022-23.xlsx
# Found .xlsx file: https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2022/11/Physical-Health-Checks-SMI-Q2-2022-23.xlsx
# Downloaded: Physical-Health-Checks-SMI-Q2-2022-23.xlsx
# Found .xlsx file: https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2022/08/Physical-Health-Checks-SMI-Q1-2022-23.xlsx
# Downloaded: Physical-Health-Checks-SMI-Q1-2022-23.xlsx
# Found .xlsx file: https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2022/05/Physical-Health-Checks-SMI-Q4-2021-22.xlsx
# Downloaded: Physical-Health-Checks-SMI-Q4-2021-22.xlsx
# Found .xlsx file: https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2022/02/Physical-Health-Checks-SMI-Q3-2021-22.xlsx
# Downloaded: Physical-Health-Checks-SMI-Q3-2021-22.xlsx
# Found .xlsx file: https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2021/11/Physical-Health-Checks-SMI-Q2-2021-22.xlsx
# Downloaded: Physical-Health-Checks-SMI-Q2-2021-22.xlsx
# Found .xlsx file: https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2021/08/Physical-Health-Checks-SMI-Q1-2021-22.xlsx
# Downloaded: Physical-Health-Checks-SMI-Q1-2021-22.xlsx
# Found .xlsx file: https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2021/05/Physical-Health-Checks-SMI-Q4-2020-21.xlsx
# Downloaded: Physical-Health-Checks-SMI-Q4-2020-21.xlsx
# Found .xlsx file: https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2021/02/Physical-Health-Checks-SMI-Q3-2020-21.xlsx
# Downloaded: Physical-Health-Checks-SMI-Q3-2020-21.xlsx
# Found .xlsx file: https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2020/11/Physical-Health-Checks-SMI-Q2-2020-21-v1.1-1.xlsx
# Downloaded: Physical-Health-Checks-SMI-Q2-2020-21-v1.1-1.xlsx
# Found .xlsx file: https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2020/08/Physical-Health-Checks-SMI-Q1-2020-21-v1.0.xlsx
# Downloaded: Physical-Health-Checks-SMI-Q1-2020-21-v1.0.xlsx
# Found .xlsx file: https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2020/05/Physical-Health-Checks-SMI-Q4-2019-20-v1.0.xlsx
# Downloaded: Physical-Health-Checks-SMI-Q4-2019-20-v1.0.xlsx
# Found .xlsx file: https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2020/02/Physical-Health-Checks-SMI-Q3-2019-20-v1.0.xlsx
# Downloaded: Physical-Health-Checks-SMI-Q3-2019-20-v1.0.xlsx
# Found .xlsx file: https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2019/11/Physical-Health-Checks-SMI-Q2-2019-20-v1.0.xlsx
# Downloaded: Physical-Health-Checks-SMI-Q2-2019-20-v1.0.xlsx
# Found .xlsx file: https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2019/08/Physical-Health-Checks-SMI-Q1-2019-20-v1.0.xlsx
# Downloaded: Physical-Health-Checks-SMI-Q1-2019-20-v1.0.xlsx
# Found .xlsx file: https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2019/05/Physical-Health-Checks-SMI-Q4-2018-19-v1.0.xlsx
# Downloaded: Physical-Health-Checks-SMI-Q4-2018-19-v1.0.xlsx
# Found .xlsx file: https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2019/02/Physical-Health-Checks-SMI-2018-19-Q3-v1.0.xlsx
# Downloaded: Physical-Health-Checks-SMI-2018-19-Q3-v1.0.xlsx

# %% [markdown]
# ### Scrape information from a table on a webpage
#
# For example, if you wanted to scrape a publication schedule, or in this case a submission schedule for Providers' MHSDS data

# %%
url4 = ('https://digital.nhs.uk/data-and-information/data-collections-and-data-sets/data-sets/mental-health-services-data-set/submit-data')

response4 = req.get(url4)

if response4.status_code == 200:
    soup4 = BeautifulSoup(response4.content, "html.parser")

tables = soup4.find_all('table') # 
print(type(tables))

table_df = pd.read_html(str(tables))[0] # get the first item in the beautifulsoup ResultSet, convert it into a string, and read the html into a pandas DataFrame

table_df
# Out:
# <class 'bs4.element.ResultSet'>
# C:\Users\edward.chick\AppData\Local\Temp\ipykernel_1752\2781751592.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   table_df = pd.read_html(str(tables))[0] # get the first item in the beautifulsoup ResultSet, convert it into a string, and read the html into a pandas DataFrame
#   Performance month Performance month restrictive interventions  \
# 0             April                              Not applicable
# 1               May                                       April
# 2              June                                         May
# 3              July                                        June
# 4            August                                        July
# 5         September                                      August
# 6           October                       September and October
#
#                         Updates/Resubmissions Cut of data taken at 11:59:59pm
# 0                              Not applicable                    17 June 2024
# 1                                      April1                    26 June 2024
# 2                                 April, May1                    24 July 2024
# 3                           April, May, June1                  27 August 2024
# 4                     April, May, June, July1               25 September 2024
# 5              April, May, June, July August1                 24 October 2024
# 6  April, May, June, July, August, September1                26 November 2024

# %% [markdown]
# Doesn't appear to cover the whole year. Is there another section to the table?

# %%
len(pd.read_html((str(tables)))) # check how many individual tables have been found
# Out:
# C:\Users\edward.chick\AppData\Local\Temp\ipykernel_1752\3497495591.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   len(pd.read_html((str(tables)))) # check how many individual tables have been found
# 2

# %%
table_df2 = pd.read_html(str(tables))[1] # return the second item from the ResultSet


table_df2
# Out:
# C:\Users\edward.chick\AppData\Local\Temp\ipykernel_1752\4174828920.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   table_df2 = pd.read_html(str(tables))[1] # return the second item from the ResultSet
#   Performance month                              Updates/Resubmissions  \
# 0          November  April, May, June, July, August, September, Oct...
# 1          December  April, May, June, July, August, September, Oct...
# 2           January  April, May, June, July, August, September, Oct...
# 3          February  April, May, June, July, August, September, Oct...
# 4             March  April, May, June, July, August, September, Oct...
#
#   Cut of data taken at 11:59:59pm
# 0                20 December 2024
# 1                 27 January 2025
# 2                25 February 2025
# 3                   25 March 2025
# 4                 To be confirmed

# %% [markdown]
# ### Using urljoin to construct URLs
#
# This will extract any .csv files for the calendar year 2024, which are all saved to their individual web pages, meaning that urljoin is required to construct the URLs dynamically (i.e. so that you don't have to hard code all the indidual web pages).
#
# The package "re" is imported so that regular expression logic can be used in the construction of the URLs i.e. anything matching the patterm of the regular expression will be considered a web page of interest. (NOTE: you do not need to install "re", it is native to Python)
#
# It's been limited to 2024 files to reduce the amount of data being transferred, but you could use a different regular expression to cover more.

# %%
from urllib.parse import urljoin
import re

url5 = 'https://digital.nhs.uk/data-and-information/publications/statistical/learning-disabilities-health-check-scheme'

target_urls = []                           # empty list that will later get filled with target URLs in a for loop.

dynamic_section = r'^england-[a-z]+-2024$' # the regular expression for the URLs we are interested in. note that the $ implies that you don't want anything else to follow.

response5 = req.get(url5)                  # get the response from the base URL

if response5.status_code == 200:
    soup5 = BeautifulSoup(response5.content, "html.parser")     # if there is a successful response, create a BeautifulSoup object.

    for link in soup5.find_all('a', href = True):
        sublink = link["href"]
        if re.match(dynamic_section,sublink.split('/')[-1]):
            full_url = urljoin(url5, sublink)                   # for each of the instances of the pattern we are looking for
            target_urls.append(full_url)                        # add the constructed full URL to a list of target URLs
        
    for link in target_urls:                                    # check for a successful response (code 200) from each URL
        response = req.get(link)                                # and create a BeautifulSoup object for each.
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, "html.parser")

            for link in soup.find_all("a", href=True):          # for each URL found on each of the pages in target_urls...
                file_url = link['href']                         

                if file_url.endswith(('.csv')):                 # ... check for .csv file extensions
                    print("Found .csv file:", file_url)

                    file_name = file_url.split("/")[-1]         # extract the file name from the URL i.e. everything after the last /
                    file_response = req.get(file_url)           # check the response for each file
            
                    if file_response.status_code == 200:        # if there's a successful response
                        
                        with open(file_name, "wb") as file:     # save the file to the current directory
                            file.write(file_response.content)
                        print(f"Downloaded: {file_name}")
                    else:
                        print(f"Failed to download: {file_url}")

else:
    print(f'Failed to fetch webpage: {response.status_code}')   # this else statement pairs with the original response code check for the base URL
                                                                # (see the first "if" in this code block)
# Out:
# Found .csv file: https://files.digital.nhs.uk/1E/56812A/learning-disabilities-health-check-scheme-eng-Sep-2024.csv
# Downloaded: learning-disabilities-health-check-scheme-eng-Sep-2024.csv
# Found .csv file: https://files.digital.nhs.uk/1C/BF3E28/learning-disabilities-health-check-scheme-eng-Aug-2024.csv
# Downloaded: learning-disabilities-health-check-scheme-eng-Aug-2024.csv
# Found .csv file: https://files.digital.nhs.uk/0C/DC2F3D/learning-disabilities-health-check-scheme-eng-Jul-2024.csv
# Downloaded: learning-disabilities-health-check-scheme-eng-Jul-2024.csv
# Found .csv file: https://files.digital.nhs.uk/BF/E282F0/learning-disabilities-health-check-scheme-eng-Jun-2024.csv
# Downloaded: learning-disabilities-health-check-scheme-eng-Jun-2024.csv
# Found .csv file: https://files.digital.nhs.uk/71/2A817F/learning-disabilities-health-check-scheme-eng-May-2024.csv
# Downloaded: learning-disabilities-health-check-scheme-eng-May-2024.csv
# Found .csv file: https://files.digital.nhs.uk/A7/B01710/learning-disabilities-health-check-scheme-eng-Apr-2024.csv
# Downloaded: learning-disabilities-health-check-scheme-eng-Apr-2024.csv
# Found .csv file: https://files.digital.nhs.uk/61/2C1997/learning-disabilities-health-check-scheme-eng-Mar-2024.csv
# Downloaded: learning-disabilities-health-check-scheme-eng-Mar-2024.csv
# Found .csv file: https://files.digital.nhs.uk/DD/8677F7/learning-disabilities-health-check-scheme-eng-Feb-2024.csv
# Downloaded: learning-disabilities-health-check-scheme-eng-Feb-2024.csv

# %%
urlpop = ('https://www.worldometers.info/world-population/population-by-country/')

responsepop = req.get(urlpop)

if responsepop.status_code == 200:
    souppop = BeautifulSoup(responsepop.content, "html.parser")

poptable = souppop.find_all('table') # 
print(type(poptable))

poptable_df = pd.read_html(str(poptable))[0] # get the first item in the beautifulsoup ResultSet, convert it into a string, and read the html into a pandas DataFrame

poptable_df
# Out:
# <class 'bs4.element.ResultSet'>
# C:\Users\edward.chick\AppData\Local\Temp\ipykernel_1752\879705101.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   poptable_df = pd.read_html(str(poptable))[0] # get the first item in the beautifulsoup ResultSet, convert it into a string, and read the html into a pandas DataFrame
#        # Country (or dependency)  Population  (2024) Yearly  Change  \
# 0      1                   India          1450935791         0.89 %
# 1      2                   China          1419321278        -0.23 %
# 2      3           United States           345426571         0.57 %
# 3      4               Indonesia           283487931         0.82 %
# 4      5                Pakistan           251269164         1.52 %
# ..   ...                     ...                 ...            ...
# 229  230              Montserrat                4389        -0.70 %
# 230  231        Falkland Islands                3470        -0.20 %
# 231  232                 Tokelau                2506         4.55 %
# 232  233                    Niue                1819         0.11 %
# 233  234                Holy See                 496         0.00 %
#
#      Net  Change  Density  (P/Km²)  Land Area  (Km²)  Migrants  (net)  \
# 0       12866195               488           2973190          -630830
# 1       -3263655               151           9388211          -318992
# 2        1949236                38           9147420          1286132
# 3        2297864               156           1811570           -38469
# 4        3764669               326            770880         -1401173
# ..           ...               ...               ...              ...
# 229          -31                44               100               -7
# 230           -7                 0             12170              -13
# 231          109               251                10               72
# 232            2                 7               260               10
# 233            0              1240                 0               18
#
#      Fert.  Rate  Med.  Age Urban  Pop % World  Share
# 0            2.0         28         37 %      17.78 %
# 1            1.0         40         66 %      17.39 %
# 2            1.6         38         82 %       4.23 %
# 3            2.1         30         59 %       3.47 %
# 4            3.5         20         34 %       3.08 %
# ..           ...        ...          ...          ...
# 229          1.4         42         11 %       0.00 %
# 230          1.7         42         68 %       0.00 %
# 231          2.6         27          0 %       0.00 %
# 232          2.5         36         44 %       0.00 %
# 233          1.0         59         N.A.       0.00 %
#
# [234 rows x 12 columns]

# %%
poptable_df.to_csv('population.csv')
